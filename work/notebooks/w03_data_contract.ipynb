# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat123design/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Akshat123design/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# One row represents one actual unit from the dataset over the selected time window of March 2026 (month=2026-03). I will verify the row grain, row count, and date span using SQL queries below.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ### Features
#
# I will use historical fields that are available at the decision moment.
#
# ### Label
#
# I will use the target or proxy that I want to predict.
#
# ### Context
#
# I will use the month and date fields to identify the time period.
#
# ### Excluded
#
# I will exclude future information and any label-derived fields from the features because they would cause data leakage.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I will verify my data contract using exactly three SQL queries:
#
# 1. Grain: Verify that one row represents the actual unit stated in Section 1.
# 2. Counts and windows: Count the rows for March 2026 and check the minimum and maximum dates.
# 3. Availability: Use IS TRUE to check how many rows have the required data available.
#
# The query outputs will provide evidence for my contract claims.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **Data limitation:** This dataset cannot tell me whether a future outcome was caused by a specific action or change. It contains historical observations, but it cannot prove causation.
#
# I will use March 2026 as my development month and keep the final month, June 2026, as a sealed test month. I will exclude future information and label-derived fields from my features to avoid data leakage.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
